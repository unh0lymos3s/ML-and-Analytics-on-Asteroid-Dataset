# %%
import pandas as pd
import warnings 
import numpy as np
import matplotlib.pyplot as plt

# %%
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(r"C:\Users\moosa\OneDrive\Desktop\asteroid.csv")

# %%
df = dataset[:100000]

# %%
df
# Out:
#              id    spkid                       full_name    pdes  \
# 0      a0000001  2000001                         1 Ceres       1
# 1      a0000002  2000002                        2 Pallas       2
# 2      a0000003  2000003                          3 Juno       3
# 3      a0000004  2000004                         4 Vesta       4
# 4      a0000005  2000005                       5 Astraea       5
# ...         ...      ...                             ...     ...
# 99995  a0099996  2099996               99996 (1981 EJ45)   99996
# 99996  a0099997  2099997               99997 (1981 EN45)   99997
# 99997  a0099998  2099998               99998 (1981 ED48)   99998
# 99998  a0099999  2099999                 99999 (1981 FP)   99999
# 99999  a0100000  2100000  100000 Astronautica (1982 SH1)  100000
#
#                name prefix neo pha      H  diameter  ...       sigma_i  \
# 0             Ceres    NaN   N   N   3.40   939.400  ...  4.610000e-09
# 1            Pallas    NaN   N   N   4.20   545.000  ...  3.470000e-06
# 2              Juno    NaN   N   N   5.33   246.596  ...  3.220000e-06
# 3             Vesta    NaN   N   N   3.00   525.400  ...  2.170000e-07
# 4           Astraea    NaN   N   N   6.90   106.699  ...  2.740000e-06
# ...             ...    ...  ..  ..    ...       ...  ...           ...
# 99995           NaN    NaN   N   N  15.00     5.240  ...  6.180000e-06
# 99996           NaN    NaN   N   N  15.90     3.281  ...  5.030000e-06
# 99997           NaN    NaN   N   N  15.30     2.574  ...  6.110000e-06
# 99998           NaN    NaN   N   N  16.20       NaN  ...  6.520000e-06
# 99999  Astronautica    NaN   N   N  16.90       NaN  ...  6.750000e-06
#
#            sigma_om       sigma_w      sigma_ma      sigma_ad       sigma_n  \
# 0      6.170000e-08  6.620000e-08  7.820000e-09  1.110000e-11  1.200000e-12
# 1      6.270000e-06  9.130000e-06  8.860000e-06  4.960000e-09  4.650000e-10
# 2      1.660000e-05  1.770000e-05  8.110000e-06  4.360000e-09  4.410000e-10
# 3      3.880000e-07  1.790000e-07  1.210000e-06  1.650000e-09  2.610000e-10
# 4      2.890000e-05  2.980000e-05  8.300000e-06  4.730000e-09  5.520000e-10
# ...             ...           ...           ...           ...           ...
# 99995  5.800000e-05  5.980000e-05  1.480000e-05  3.480000e-08  2.620000e-09
# 99996  1.013200e-04  1.023200e-04  1.570000e-05  1.350000e-08  2.210000e-09
# 99997  2.620000e-05  3.150000e-05  1.830000e-05  2.190000e-08  2.220000e-09
# 99998  1.155900e-04  1.172000e-04  2.410000e-05  1.580000e-08  2.190000e-09
# 99999  1.170000e-05  2.790000e-05  2.370000e-05  6.910000e-09  1.880000e-09
#
#            sigma_tp     sigma_per  clas      rms
# 0      3.780000e-08  9.420000e-09   MBA  0.43301
# 1      4.080000e-05  3.680000e-06   MBA  0.35936
# 2      3.530000e-05  3.110000e-06   MBA  0.33848
# 3      4.100000e-06  1.270000e-06   MBA  0.39980
# 4      3.470000e-05  3.490000e-06   MBA  0.52191
# ...             ...           ...   ...      ...
# 99995  8.310000e-05  2.860000e-05   MBA  0.55733
# 99996  5.360000e-05  9.270000e-06   MBA  0.55597
# 99997  8.250000e-05  1.720000e-05   MBA  0.56688
# 99998  9.170000e-05  1.180000e-05   MBA  0.59563
# 99999  6.310000e-05  4.810000e-06   IMB  0.58837
#
# [100000 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 45 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              100000 non-null  object
#  1   spkid           100000 non-null  int64
#  2   full_name       100000 non-null  object
#  3   pdes            100000 non-null  object
#  4   name            19363 non-null   object
#  5   prefix          0 non-null       object
#  6   neo             100000 non-null  object
#  7   pha             100000 non-null  object
#  8   H               100000 non-null  float64
#  9   diameter        57628 non-null   float64
#  10  albedo          57604 non-null   float64
#  11  diameter_sigma  57520 non-null   float64
#  12  orbit_id        100000 non-null  object
#  13  epoch           100000 non-null  float64
#  14  epoch_mjd       100000 non-null  int64
#  15  epoch_cal       100000 non-null  int64
#  16  equinox         100000 non-null  object
#  17  e               100000 non-null  float64
#  18  a               100000 non-null  float64
#  19  q               100000 non-null  float64
#  20  i               100000 non-null  float64
#  21  om              100000 non-null  float64
#  22  w               100000 non-null  float64
#  23  ma              100000 non-null  float64
#  24  ad              100000 non-null  float64
#  25  n               100000 non-null  float64
#  26  tp              100000 non-null  float64
#  27  tp_cal          100000 non-null  float64
#  28  per             100000 non-null  float64
#  29  per_y           100000 non-null  float64
#  30  moid            100000 non-null  float64
#  31  moid_ld         100000 non-null  float64
#  32  sigma_e         100000 non-null  float64
#  33  sigma_a         100000 non-null  float64
#  34  sigma_q         100000 non-null  float64
#  35  sigma_i         100000 non-null  float64
#  36  sigma_om        100000 non-null  float64
#  37  sigma_w         100000 non-null  float64
#  38  sigma_ma        100000 non-null  float64
#  39  sigma_ad        100000 non-null  float64
#  40  sigma_n         100000 non-null  float64
#  41  sigma_tp        100000 non-null  float64
#  42  sigma_per       100000 non-null  float64
#  43  clas            100000 non-null  object
#  44  rms             100000 non-null  float64
# dtypes: float64(32), int64(3), object(10)
# memory usage: 34.3+ MB

# %%
#selecting features that seem important
df_selected = ['neo','pha','H','diameter','albedo','diameter_sigma','e','a','q','i','tp','moid_ld','clas']

# %%
df = df[df_selected]

# %%
df.head()
# Out:
#   neo pha     H  diameter  albedo  diameter_sigma         e         a  \
# 0   N   N  3.40   939.400  0.0900           0.200  0.076009  2.769165
# 1   N   N  4.20   545.000  0.1010          18.000  0.229972  2.773841
# 2   N   N  5.33   246.596  0.2140          10.594  0.256936  2.668285
# 3   N   N  3.00   525.400  0.4228           0.200  0.088721  2.361418
# 4   N   N  6.90   106.699  0.2740           3.140  0.190913  2.574037
#
#           q          i           tp     moid_ld clas
# 0  2.558684  10.594067  2458238.754  620.640533  MBA
# 1  2.135935  34.832932  2458320.962  480.348639  MBA
# 2  1.982706  12.991043  2458445.792  402.514639  MBA
# 3  2.151909   7.141771  2458247.560  443.451432  MBA
# 4  2.082619   5.367427  2458925.723  426.433027  MBA

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
encoder.fit(df.neo)
df['neo'] = encoder.transform(df.neo)
df['pha'] = encoder.fit_transform(df.pha)
df['clas'] = encoder.fit_transform(df.clas)

# %%
df
# Out:
#        neo  pha      H  diameter  albedo  diameter_sigma         e         a  \
# 0        0    0   3.40   939.400  0.0900           0.200  0.076009  2.769165
# 1        0    0   4.20   545.000  0.1010          18.000  0.229972  2.773841
# 2        0    0   5.33   246.596  0.2140          10.594  0.256936  2.668285
# 3        0    0   3.00   525.400  0.4228           0.200  0.088721  2.361418
# 4        0    0   6.90   106.699  0.2740           3.140  0.190913  2.574037
# ...    ...  ...    ...       ...     ...             ...       ...       ...
# 99995    0    0  15.00     5.240  0.0590           0.129  0.172829  3.088414
# 99996    0    0  15.90     3.281  0.0720           0.746  0.197557  2.244647
# 99997    0    0  15.30     2.574  0.2670           0.388  0.155305  2.756943
# 99998    0    0  16.20       NaN     NaN             NaN  0.141855  2.443526
# 99999    0    0  16.90       NaN     NaN             NaN  0.087277  1.904930
#
#               q          i           tp     moid_ld  clas
# 0      2.558684  10.594067  2458238.754  620.640533     6
# 1      2.135935  34.832932  2458320.962  480.348639     6
# 2      1.982706  12.991043  2458445.792  402.514639     6
# 3      2.151909   7.141771  2458247.560  443.451432     6
# 4      2.082619   5.367427  2458925.723  426.433027     6
# ...         ...        ...          ...         ...   ...
# 99995  2.554647   4.585400  2459272.561  600.485418     6
# 99996  1.801200   3.250248  2459052.050  317.287966     6
# 99997  2.328777   8.721171  2458449.675  516.323514     6
# 99998  2.096899   2.416043  2458704.854  425.930998     6
# 99999  1.738673  21.184332  2458736.237  289.813342     5
#
# [100000 rows x 13 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        neo  pha      H  diameter  albedo  diameter_sigma         e         a  \
# 0        0    0   3.40   939.400  0.0900           0.200  0.076009  2.769165
# 1        0    0   4.20   545.000  0.1010          18.000  0.229972  2.773841
# 2        0    0   5.33   246.596  0.2140          10.594  0.256936  2.668285
# 3        0    0   3.00   525.400  0.4228           0.200  0.088721  2.361418
# 4        0    0   6.90   106.699  0.2740           3.140  0.190913  2.574037
# ...    ...  ...    ...       ...     ...             ...       ...       ...
# 99995    0    0  15.00     5.240  0.0590           0.129  0.172829  3.088414
# 99996    0    0  15.90     3.281  0.0720           0.746  0.197557  2.244647
# 99997    0    0  15.30     2.574  0.2670           0.388  0.155305  2.756943
# 99998    0    0  16.20       NaN     NaN             NaN  0.141855  2.443526
# 99999    0    0  16.90       NaN     NaN             NaN  0.087277  1.904930
#
#               q          i           tp     moid_ld  clas
# 0      2.558684  10.594067  2458238.754  620.640533     6
# 1      2.135935  34.832932  2458320.962  480.348639     6
# 2      1.982706  12.991043  2458445.792  402.514639     6
# 3      2.151909   7.141771  2458247.560  443.451432     6
# 4      2.082619   5.367427  2458925.723  426.433027     6
# ...         ...        ...          ...         ...   ...
# 99995  2.554647   4.585400  2459272.561  600.485418     6
# 99996  1.801200   3.250248  2459052.050  317.287966     6
# 99997  2.328777   8.721171  2458449.675  516.323514     6
# 99998  2.096899   2.416043  2458704.854  425.930998     6
# 99999  1.738673  21.184332  2458736.237  289.813342     5
#
# [100000 rows x 13 columns]>

# %%
df.head(434)
# Out:
#      neo  pha      H  diameter  albedo  diameter_sigma         e         a  \
# 0      0    0   3.40   939.400  0.0900           0.200  0.076009  2.769165
# 1      0    0   4.20   545.000  0.1010          18.000  0.229972  2.773841
# 2      0    0   5.33   246.596  0.2140          10.594  0.256936  2.668285
# 3      0    0   3.00   525.400  0.4228           0.200  0.088721  2.361418
# 4      0    0   6.90   106.699  0.2740           3.140  0.190913  2.574037
# ..   ...  ...    ...       ...     ...             ...       ...       ...
# 429    0    0  11.10    31.702  0.0540           0.661  0.252960  2.848554
# 430    0    0   8.90   101.900  0.0550           0.988  0.170334  3.140542
# 431    0    0   8.90    46.900  0.2338           0.800  0.146545  2.369576
# 432    1    0  10.40    16.840  0.2500           0.060  0.222951  1.458046
# 433    0    0  11.20     8.934  0.7260           0.748  0.073839  1.944392
#
#             q          i           tp     moid_ld  clas
# 0    2.558684  10.594067  2458238.754  620.640533     6
# 1    2.135935  34.832932  2458320.962  480.348639     6
# 2    1.982706  12.991043  2458445.792  402.514639     6
# 3    2.151909   7.141771  2458247.560  443.451432     6
# 4    2.082619   5.367427  2458925.723  426.433027     6
# ..        ...        ...          ...         ...   ...
# 429  2.127983  14.583267  2459777.466  444.521649     6
# 430  2.605600   1.827746  2458336.045  621.072511     6
# 431  2.022325  12.121138  2458916.480  391.863056     6
# 432  1.132973  10.830543  2459159.352   57.839613     0
# 433  1.800821  22.509073  2458972.867  324.792331     5
#
# [434 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# neo                   0
# pha                   0
# H                     0
# diameter          42372
# albedo            42396
# diameter_sigma    42480
# e                     0
# a                     0
# q                     0
# i                     0
# tp                    0
# moid_ld               0
# clas                  0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
plt.scatter(df['diameter'],df['H'])
plt.xlim(0,1000)
plt.ylim(0,50)
plt.xlabel('diameter')
plt.ylabel('Absolute Magnitude (H)')
plt.title('correlation between Luminosity and Diameter')

plt.show()

# %%
plt.scatter(df['albedo'],df['H'])
plt.xlim(0,1)
plt.ylim(0,25)
plt.xlabel('Albedo (Reflectiveness)')
plt.ylabel('Absolute Magnitude (H)')
plt.title('correlation between Luminosity and Reflectiveness')

plt.show()

# %%
plt.scatter(df['q'],df['H'])
plt.xlim(0,11)
plt.ylim(0,25)
plt.xlabel('Distance from Sun (q)')
plt.ylabel('Absolute Magnitude (H)')
plt.title('correlation between Luminosity and Shortest Distance from Sun')

plt.show()

# %%
plt.scatter(df['q'],df['albedo'])
plt.title('correlation between Luminosity and Shortest Distance from Sun')
plt.xlabel('Distance from Sun (q)')
plt.ylabel('Reflectiveness(Albedo)')
# Out:
# Text(0, 0.5, 'Reflectiveness(Albedo)')

# %% [markdown]
# <h1><i>Clustering

# %%
#df_n = df.drop('class', axis=1)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, verbose=0, perplexity=1, random_state=1)
#df_no_name = df.drop('name', axis=1)
TSNE_df = tsne.fit_transform(df)
plt.scatter(TSNE_df[:,0],TSNE_df[:,1])

# %%
tsne = TSNE(n_components=2, verbose=0, perplexity=50, random_state=1)

TSNE_df = tsne.fit_transform(df)
plt.scatter(TSNE_df[:,0],TSNE_df[:,1], c=data_with_clusters['Clusters'], cmap = "rainbow")

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
pca.fit(df)
PCA_df=pca.transform(df)
plt.scatter(PCA_df[:, 0], PCA_df[:,1])

# %%
from sklearn.cluster import KMeans
wcss=[]
for i in range(1,20
              ):
  kmeans = KMeans(i)
  kmeans.fit(df)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)

number_clusters = range(1,20)
plt.plot(number_clusters,wcss)
plt.title('The Elbow title')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
KMeans = KMeans(5)
KMeans.fit(df)
# Out:
# KMeans(n_clusters=5)

# %%
identified_clusters = KMeans.fit_predict(df)
identified_clusters
# Out:
# array([4, 4, 4, ..., 1, 0, 4])

# %%
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = identified_clusters
plt.scatter(df['diameter'],df['H'],c=data_with_clusters['Clusters'],cmap='rainbow')
plt.title('correlation between Luminosity and Diameter')
# Out:
# Text(0.5, 1.0, 'correlation between Luminosity and Diameter')

# %%
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = identified_clusters
plt.scatter(df['albedo'],df['H'],c=data_with_clusters['Clusters'],cmap='rainbow')
plt.title('correlation between Luminosity and Reflectiveness')
# Out:
# Text(0.5, 1.0, 'correlation between Luminosity and Reflectiveness')

# %%
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = identified_clusters
plt.scatter(df['q'],df['H'],c=data_with_clusters['Clusters'],cmap='rainbow')
plt.title('correlation between Luminosity and Shortest Distance from Sun')
# Out:
# Text(0.5, 1.0, 'correlation between Luminosity and Shortest Distance from Sun')

# %%
data_with_clusters = df.copy()
data_with_clusters['Clusters'] = identified_clusters
plt.scatter(df['q'],df['albedo'],c=data_with_clusters['Clusters'],cmap='rainbow')
plt.title('correlation between Reflectiveness and Shortest Distance from Sun')
# Out:
# Text(0.5, 1.0, 'correlation between Reflectiveness and Shortest Distance from Sun')

# %% [markdown]
# <h1> <i>Regression<i>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import train_test_split

# %%
X = df.drop('diameter', axis = 1)
Y = df['diameter']
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 0)

# %%
X
# Out:
#        neo  pha      H  albedo  diameter_sigma         e         a         q  \
# 0        0    0   3.40  0.0900           0.200  0.076009  2.769165  2.558684
# 1        0    0   4.20  0.1010          18.000  0.229972  2.773841  2.135935
# 2        0    0   5.33  0.2140          10.594  0.256936  2.668285  1.982706
# 3        0    0   3.00  0.4228           0.200  0.088721  2.361418  2.151909
# 4        0    0   6.90  0.2740           3.140  0.190913  2.574037  2.082619
# ...    ...  ...    ...     ...             ...       ...       ...       ...
# 99988    0    0  14.90  0.0510           0.218  0.108245  3.139546  2.799705
# 99992    0    0  15.30  0.0470           0.345  0.131090  3.140783  2.729058
# 99995    0    0  15.00  0.0590           0.129  0.172829  3.088414  2.554647
# 99996    0    0  15.90  0.0720           0.746  0.197557  2.244647  1.801200
# 99997    0    0  15.30  0.2670           0.388  0.155305  2.756943  2.328777
#
#                i           tp     moid_ld  clas
# 0      10.594067  2458238.754  620.640533     6
# 1      34.832932  2458320.962  480.348639     6
# 2      12.991043  2458445.792  402.514639     6
# 3       7.141771  2458247.560  443.451432     6
# 4       5.367427  2458925.723  426.433027     6
# ...          ...          ...         ...   ...
# 99988  10.201746  2459325.502  696.236805     6
# 99992   4.661389  2459134.979  670.244141     6
# 99995   4.585400  2459272.561  600.485418     6
# 99996   3.250248  2459052.050  317.287966     6
# 99997   8.721171  2458449.675  516.323514     6
#
# [57515 rows x 12 columns]

# %%
clf = LinearRegression()
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print("Linear Regression Train", clf.score(X_train,Y_train))
print("Linear Regression Test", clf.score(X_test,Y_test))
# Out:
# Linear Regression Train 0.603151921360759
# Linear Regression Test 0.43363212411953544

# %%
clf = DecisionTreeRegressor()
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
print("DecisionTree Train", clf.score(X_train,Y_train))
print("DecisionTree Test", clf.score(X_test,Y_test))
# Out:
# DecisionTree Train 1.0
# DecisionTree Test 0.9015003797286875

# %%
clf = RandomForestRegressor()
clf.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
print("RandomForest Train", clf.score(X_train,Y_train))
print("RandomForest Test", clf.score(X_test,Y_test))
# Out:
# RandomForest Train 0.9958180018621909
# RandomForest Test 0.9071013333017333

# %%
clf = GradientBoostingRegressor()
clf.fit(X_train,Y_train)
# Out:
# GradientBoostingRegressor()

# %%
print("Gradient Boosting Train", clf.score(X_train,Y_train))
print("Gradient Boosting Test", clf.score(X_test,Y_test))
# Out:
# Gradient Boosting Train 0.9907564272275635
# Gradient Boosting Test 0.9224604539008435

# %% [markdown]
# <h1><i>Classification

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
x = df.drop('clas', axis = 1)
y = df['clas']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 0)

# %%
clf = LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print("Logistic Regression Train", clf.score(x_train,y_train))
print("Logistic Regression Test", clf.score(x_test,y_test))
# Out:
# Logistic Regression Train 0.9332565417717117
# Logistic Regression Test 0.9355820220811962

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("DecisionTree Train", clf.score(x_train,y_train))
print("DecisionTree Test", clf.score(x_test,y_test))
# Out:
# DecisionTree Train 1.0
# DecisionTree Test 0.9999130661566548

# %%
clf = RandomForestClassifier()
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
print("DecisionTree Train", clf.score(x_train,y_train))
print("DecisionTree Test", clf.score(x_test,y_test))
# Out:
# DecisionTree Train 1.0
# DecisionTree Test 0.9996522646266192

# %%
clf = GradientBoostingClassifier(max_depth = 1)
clf.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(max_depth=1)

# %%
print("GradientBoosting Train", clf.score(x_train,y_train))
print("GradientBoosting Test", clf.score(x_test,y_test))
# Out:
# GradientBoosting Train 0.9988698600365122
# GradientBoosting Test 0.9984351908197862

# %% [markdown]
# <h1><i>Anomaly Detection

# %%
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.cluster import DBSCAN

# %%
clf = IsolationForest(contamination=0.07, random_state=42)
clf.fit(df)
# Out:
# IsolationForest(contamination=0.07, random_state=42)

# %%
y_pred = clf.predict(df)

# %%
df['anomaly'] = y_pred

# %%
df
# Out:
#        neo  pha      H  diameter  albedo  diameter_sigma         e         a  \
# 0        0    0   3.40   939.400  0.0900           0.200  0.076009  2.769165
# 1        0    0   4.20   545.000  0.1010          18.000  0.229972  2.773841
# 2        0    0   5.33   246.596  0.2140          10.594  0.256936  2.668285
# 3        0    0   3.00   525.400  0.4228           0.200  0.088721  2.361418
# 4        0    0   6.90   106.699  0.2740           3.140  0.190913  2.574037
# ...    ...  ...    ...       ...     ...             ...       ...       ...
# 99988    0    0  14.90     6.177  0.0510           0.218  0.108245  3.139546
# 99992    0    0  15.30     4.651  0.0470           0.345  0.131090  3.140783
# 99995    0    0  15.00     5.240  0.0590           0.129  0.172829  3.088414
# 99996    0    0  15.90     3.281  0.0720           0.746  0.197557  2.244647
# 99997    0    0  15.30     2.574  0.2670           0.388  0.155305  2.756943
#
#               q          i           tp     moid_ld  clas  anomaly
# 0      2.558684  10.594067  2458238.754  620.640533     6       -1
# 1      2.135935  34.832932  2458320.962  480.348639     6       -1
# 2      1.982706  12.991043  2458445.792  402.514639     6       -1
# 3      2.151909   7.141771  2458247.560  443.451432     6       -1
# 4      2.082619   5.367427  2458925.723  426.433027     6       -1
# ...         ...        ...          ...         ...   ...      ...
# 99988  2.799705  10.201746  2459325.502  696.236805     6        1
# 99992  2.729058   4.661389  2459134.979  670.244141     6        1
# 99995  2.554647   4.585400  2459272.561  600.485418     6        1
# 99996  1.801200   3.250248  2459052.050  317.287966     6        1
# 99997  2.328777   8.721171  2458449.675  516.323514     6        1
#
# [57515 rows x 14 columns]

# %%
plt.scatter(df[df['anomaly']==1]['albedo'], df[df['anomaly']==1]['H'], c='blue',label='inlier')
plt.scatter(df[df['anomaly']==-1]['albedo'], df[df['anomaly']==-1]['H'], c='red',label='outlier')
plt.title('Isolation Forest Anomaly Detection')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
svm = OneClassSVM(gamma='scale', nu=0.08)
svm.fit(df)
# Out:
# OneClassSVM(nu=0.08)

# %%
y_pred_SVM = svm.predict(df)

# %%
df['anomaly_svm'] = y_pred_SVM

# %%
plt.scatter(df[df['anomaly_svm']==1]['albedo'], df[df['anomaly_svm']==1]['H'], c='blue',label='inlier')
plt.scatter(df[df['anomaly_svm']==-1]['albedo'], df[df['anomaly_svm']==-1]['H'], c='red',label='outlier')
plt.scatter(df[df['anomaly_svm']==0]['albedo'], df[df['anomaly_svm']==0]['H'], c='black',label='inlier2')

plt.title('Isolation Forest Anomaly Detection')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.show()

# %%
dbscan = DBSCAN(eps=0.1)
clusters = dbscan.fit_predict(df)

# %%
plt.scatter(df['albedo'], df['H'], c=clusters)
plt.show()
